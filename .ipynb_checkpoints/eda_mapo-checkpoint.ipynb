# %%
import pandas as pd
import numpy as np
import re
import random
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp

# %%
yp_df = pd.read_excel("../data/moving_population/ingu_hour_yeungdeungpo.xlsx",sheet_name=0)

# %%
yp_df.describe()
# Out:
#              date           hour      longitude       latitude   gu_code  \
# count    211426.0  211426.000000  211426.000000  211426.000000  211426.0
# mean   20190911.0      11.511933     126.908673      37.520760   11560.0
# std           0.0       6.919037       0.015823       0.014318       0.0
# min    20190911.0       0.000000     126.878273      37.485439   11560.0
# 25%    20190911.0       6.000000     126.896687      37.511520   11560.0
# 50%    20190911.0      12.000000     126.906707      37.521555   11560.0
# 75%    20190911.0      18.000000     126.919405      37.530913   11560.0
# max    20190911.0      23.000000     126.949853      37.555643   11560.0
#
#           dong_code   under10_ingu   under20_ingu   under30_ingu  \
# count  2.114260e+05  211426.000000  211426.000000  211426.000000
# mean   1.156059e+09       0.228387       1.253968       3.204543
# std    6.024133e+03       0.339337       1.819190       5.565384
# min    1.156052e+09       0.000000       0.000000       0.000000
# 25%    1.156054e+09       0.009036       0.079011       0.302090
# 50%    1.156056e+09       0.115537       0.661187       1.604891
# 75%    1.156062e+09       0.309218       1.687028       3.740847
# max    1.156072e+09       5.971869      30.339455     138.267928
#
#         under40_ingu  ...  upper80_male_ingu  under10_female_ingu  \
# count  211426.000000  ...      211426.000000        211426.000000
# mean        4.775726  ...           0.181288             0.131913
# std         8.187178  ...           0.254748             0.202012
# min         0.000000  ...           0.000000             0.000000
# 25%         0.485646  ...           0.009166             0.002638
# 50%         2.448828  ...           0.106722             0.062470
# 75%         5.649971  ...           0.251459             0.178894
# max       222.507677  ...           6.825863             3.836334
#
#        under20_female_ingu  under30_female_ingu  under40_female_ingu  \
# count        211426.000000        211426.000000        211426.000000
# mean              0.604070             1.727053             2.209978
# std               0.903035             3.148774             3.714099
# min               0.000000             0.000000             0.000000
# 25%               0.035644             0.147897             0.208485
# 50%               0.310205             0.820556             1.144200
# 75%               0.803419             1.960525             2.652754
# max              18.295030            82.540771            90.543966
#
#        under50_female_ingu  under60_female_ingu  under70_female_ingu  \
# count        211426.000000        211426.000000        211426.000000
# mean              2.103090             1.832086             1.414956
# std               3.088622             2.483981             1.825269
# min               0.000000             0.000000             0.000000
# 25%               0.188384             0.160412             0.113010
# 50%               1.209982             1.137155             0.909676
# 75%               2.689145             2.484599             1.966359
# max              60.862535            47.005390            57.673513
#
#        under80_female_ingu  upper80_female_ingu
# count        211426.000000        211426.000000
# mean              0.695179             0.204815
# std               0.929653             0.276714
# min               0.000000             0.000000
# 25%               0.045846             0.011342
# 50%               0.443922             0.123530
# 75%               0.975287             0.285818
# max              51.395132             7.455296
#
# [8 rows x 33 columns]

# %%
yp_df_debug = yp_df.loc[:,['hour','under40_ingu','under40_male_ingu','under40_female_ingu']]
yp_df_debug
# Out:
#         hour  under40_ingu  under40_male_ingu  under40_female_ingu
# 0          0      5.060689           2.620277             2.440412
# 1          0      8.151856           4.607122             3.544734
# 2          0      1.070060           0.652133             0.417927
# 3          0     10.584853           5.180394             5.404459
# 4          0      2.915421           1.585708             1.329714
# ...      ...           ...                ...                  ...
# 211421    23      3.621903           1.906360             1.715543
# 211422    23     11.491260           6.690967             4.800293
# 211423    23      6.043692           3.087390             2.956302
# 211424    23      1.740849           0.921187             0.819663
# 211425    23      2.156039           1.180828             0.975211
#
# [211426 rows x 4 columns]

# %%
x = yp_df_debug.groupby('hour').sum()
x['debug'] = x.apply(lambda row:row['under40_male_ingu']+row['under40_female_ingu'],axis=1)
x
# Out:
#       under40_ingu  under40_male_ingu  under40_female_ingu         debug
# hour
# 0     35296.808777       18902.403664         16394.405113  35296.808777
# 1     34898.734593       18640.863312         16257.871281  34898.734593
# 2     34496.777934       18403.949750         16092.828184  34496.777934
# 3     34289.909352       18234.471277         16055.438075  34289.909352
# 4     34156.360029       18131.543055         16024.816974  34156.360029
# 5     34367.110132       18260.077264         16107.032868  34367.110132
# 6     35676.025422       19191.227824         16484.797598  35676.025422
# 7     43849.349269       23908.536643         19940.812626  43849.349269
# 8     49871.921932       27205.436624         22666.485308  49871.921932
# 9     51408.611008       27925.021695         23483.589312  51408.611008
# 10    51978.983617       28102.300655         23876.682962  51978.983617
# 11    52692.665131       28481.688813         24210.976319  52692.665131
# 12    52489.494041       28191.976351         24297.517690  52489.494041
# 13    51436.451518       27759.860234         23676.591285  51436.451518
# 14    50496.337748       27191.851478         23304.486270  50496.337748
# 15    49568.427528       26732.470094         22835.957434  49568.427528
# 16    48209.765490       25870.470116         22339.295374  48209.765490
# 17    45044.410545       24077.015226         20967.395319  45044.410545
# 18    41822.296037       22369.768956         19452.527081  41822.296037
# 19    38831.779525       20657.364055         18174.415470  38831.779525
# 20    36990.405317       19655.767101         17334.638216  36990.405317
# 21    35301.778385       18884.332965         16417.445420  35301.778385
# 22    33804.897327       18122.135667         15682.761660  33804.897327
# 23    32733.323606       17565.330852         15167.992754  32733.323606

# %%
yp_df.head()
# Out:
#        date  hour   longitude   latitude  gu_code gu_name   dong_code  \
# 0  20190911     0  126.904651  37.510243    11560    영등포구  1156051500
# 1  20190911     0  126.917051  37.516164    11560    영등포구  1156051500
# 2  20190911     0  126.911425  37.512080    11560    영등포구  1156051500
# 3  20190911     0  126.901812  37.511581    11560    영등포구  1156051500
# 4  20190911     0  126.913667  37.514795    11560    영등포구  1156051500
#
#   dong_name  under10_ingu  under20_ingu  ...  upper80_male_ingu  \
# 0     영등포본동      0.477690      2.295678  ...           0.291999
# 1     영등포본동      0.261749      2.162063  ...           0.387504
# 2     영등포본동      0.003061      0.223033  ...           0.103522
# 3     영등포본동      0.683299      4.209149  ...           0.359653
# 4     영등포본동      0.218001      1.505187  ...           0.189097
#
#    under10_female_ingu  under20_female_ingu  under30_female_ingu  \
# 0             0.291928             0.916024             1.710428
# 1             0.149363             0.938860             3.624611
# 2             0.003061             0.133585             0.390273
# 3             0.265973             1.946447             3.184111
# 4             0.141304             0.692433             0.846153
#
#    under40_female_ingu  under50_female_ingu  under60_female_ingu  \
# 0             2.440412             3.262780             2.892460
# 1             3.544734             2.772231             2.820026
# 2             0.417927             0.513422             0.516027
# 3             5.404459             4.894257             5.373596
# 4             1.329714             1.272188             1.615956
#
#    under70_female_ingu  under80_female_ingu  upper80_female_ingu
# 0             2.045463             1.043423             0.272596
# 1             2.407307             1.139865             0.194348
# 2             0.547065             0.373192             0.124435
# 3             2.858021             1.359324             0.362667
# 4             1.570745             0.773648             0.163622
#
# [5 rows x 35 columns]

# %%
ingu_var = [x for x in yp_df.columns if '_ingu' in x]
print(len(ingu_var))
# Out:
# 27

# %%
yp_df_2 = pd.melt(yp_df,['hour','gu_name','dong_name'],value_vars=ingu_var,var_name='성별연령대',value_name='인구')
yp_df_2.head()
# Out:
#    hour gu_name dong_name         성별연령대        인구
# 0     0    영등포구     영등포본동  under10_ingu  0.477690
# 1     0    영등포구     영등포본동  under10_ingu  0.261749
# 2     0    영등포구     영등포본동  under10_ingu  0.003061
# 3     0    영등포구     영등포본동  under10_ingu  0.683299
# 4     0    영등포구     영등포본동  under10_ingu  0.218001

# %%
yp_df_2['연령대'] = yp_df_2['성별연령대'].str.slice(stop=7)
yp_df_2.head()
# Out:
#    hour gu_name dong_name         성별연령대        인구      연령대
# 0     0    영등포구     영등포본동  under10_ingu  0.477690  under10
# 1     0    영등포구     영등포본동  under10_ingu  0.261749  under10
# 2     0    영등포구     영등포본동  under10_ingu  0.003061  under10
# 3     0    영등포구     영등포본동  under10_ingu  0.683299  under10
# 4     0    영등포구     영등포본동  under10_ingu  0.218001  under10

# %%
yp_df_2['성별'] = yp_df_2['성별연령대'].str.slice(start=8)
yp_df_2.head()
# Out:
#    hour gu_name dong_name         성별연령대        인구      연령대    성별
# 0     0    영등포구     영등포본동  under10_ingu  0.477690  under10  ingu
# 1     0    영등포구     영등포본동  under10_ingu  0.261749  under10  ingu
# 2     0    영등포구     영등포본동  under10_ingu  0.003061  under10  ingu
# 3     0    영등포구     영등포본동  under10_ingu  0.683299  under10  ingu
# 4     0    영등포구     영등포본동  under10_ingu  0.218001  under10  ingu

# %%
yp_df_2[yp_df_2['성별']=='ingu']['성별'].value_counts()
# Out:
# ingu    1902834
# Name: 성별, dtype: int64

# %%
yp_df_2[yp_df_2['성별']=='male_ingu']['성별'].value_counts()
# Out:
# male_ingu    1902834
# Name: 성별, dtype: int64

# %%
yp_df_2[yp_df_2['성별']=='female_ingu']['성별'].value_counts()
# Out:
# female_ingu    1902834
# Name: 성별, dtype: int64

# %%
yp_df_2_temp = yp_df_2[yp_df_2['성별']=='ingu'].groupby('연령대').sum()
yp_df_2_temp['남성'] = yp_df_2[yp_df_2['성별']=='male_ingu'].groupby('연령대').sum()['인구']
yp_df_2_temp['여성'] = yp_df_2[yp_df_2['성별']=='female_ingu'].groupby('연령대').sum()['인구']
# Out:
#             hour            인구             남성             여성
# 연령대
# under10  2433922  4.828687e+04   20384.971544   27889.897443
# under20  2433922  2.651214e+05  137405.348440  127716.003376
# under30  2433922  6.775238e+05  312379.936118  365143.832466
# under40  2433922  1.009713e+06  542465.863670  467246.760592
# under50  2433922  9.820769e+05  537428.996356  444647.905946
# under60  2433922  8.294496e+05  442098.908654  387350.664030
# under70  2433922  6.125673e+05  313408.928184  299158.394947
# under80  2433922  2.990608e+05  152081.866403  146978.925433
# upper80  2433922  6.520807e+05   38328.927985   43303.173608

# %%
yp_df_2_temp['남녀합'] = yp_df_2_temp.apply(lambda row:row['남성']+row['여성'],axis=1)
yp_df_2_temp.loc[:,['남성','여성','남녀합','인구']]
# Out:
#                     남성             여성           남녀합            인구
# 연령대
# under10   20384.971544   27889.897443  4.827487e+04  4.828687e+04
# under20  137405.348440  127716.003376  2.651214e+05  2.651214e+05
# under30  312379.936118  365143.832466  6.775238e+05  6.775238e+05
# under40  542465.863670  467246.760592  1.009713e+06  1.009713e+06
# under50  537428.996356  444647.905946  9.820769e+05  9.820769e+05
# under60  442098.908654  387350.664030  8.294496e+05  8.294496e+05
# under70  313408.928184  299158.394947  6.125673e+05  6.125673e+05
# under80  152081.866403  146978.925433  2.990608e+05  2.990608e+05
# upper80   38328.927985   43303.173608  8.163210e+04  6.520807e+05

# %%
yp_df_2_temp.rename(columns={'남성': 'male', '여성': 'female','남녀합':'sum','인구':'ingu'}, inplace=True)

# %%
yp_df_2['연령대'].unique()
# Out:
# array(['under10', 'under20', 'under30', 'under40', 'under50', 'under60',
#        'under70', 'under80', 'upper80'], dtype=object)

# %%
analysis_age = yp_df_2_temp.loc[:,['male','female','sum']]
analysis_age['age'] = yp_df_2['연령대'].unique()
ax = analysis_age.plot.bar(x='age', rot=0)
plt.savefig('analysis_age_yp.png')

# %%
yp_df_unisex = yp_df_2[yp_df_2['성별']=='ingu']
yp_df_2 = yp_df_2[yp_df_2['성별']!='ingu']

# %%
yp_df_unisex
# Out:
#          hour gu_name dong_name         성별연령대         인구      연령대    성별
# 0           0    영등포구     영등포본동  under10_ingu   0.477690  under10  ingu
# 1           0    영등포구     영등포본동  under10_ingu   0.261749  under10  ingu
# 2           0    영등포구     영등포본동  under10_ingu   0.003061  under10  ingu
# 3           0    영등포구     영등포본동  under10_ingu   0.683299  under10  ingu
# 4           0    영등포구     영등포본동  under10_ingu   0.218001  under10  ingu
# ...       ...     ...       ...           ...        ...      ...   ...
# 1902829    23    영등포구      대림3동  upper80_ingu   9.071258  upper80  ingu
# 1902830    23    영등포구      대림3동  upper80_ingu  58.744651  upper80  ingu
# 1902831    23    영등포구      대림3동  upper80_ingu   8.823525  upper80  ingu
# 1902832    23    영등포구      대림3동  upper80_ingu   0.984444  upper80  ingu
# 1902833    23    영등포구      대림3동  upper80_ingu   1.797984  upper80  ingu
#
# [1902834 rows x 7 columns]

# %%
yp_df_2[yp_df_2['성별']=='male_ingu']
# Out:
#          hour gu_name dong_name              성별연령대        인구      연령대  \
# 1902834     0    영등포구     영등포본동  under10_male_ingu  0.185763  under10
# 1902835     0    영등포구     영등포본동  under10_male_ingu  0.112386  under10
# 1902836     0    영등포구     영등포본동  under10_male_ingu  0.000000  under10
# 1902837     0    영등포구     영등포본동  under10_male_ingu  0.417325  under10
# 1902838     0    영등포구     영등포본동  under10_male_ingu  0.076697  under10
# ...       ...     ...       ...                ...       ...      ...
# 3805663    23    영등포구      대림3동  upper80_male_ingu  0.338828  upper80
# 3805664    23    영등포구      대림3동  upper80_male_ingu  0.607740  upper80
# 3805665    23    영등포구      대림3동  upper80_male_ingu  0.456893  upper80
# 3805666    23    영등포구      대림3동  upper80_male_ingu  0.040895  upper80
# 3805667    23    영등포구      대림3동  upper80_male_ingu  0.113620  upper80
#
#                 성별
# 1902834  male_ingu
# 1902835  male_ingu
# 1902836  male_ingu
# 1902837  male_ingu
# 1902838  male_ingu
# ...            ...
# 3805663  male_ingu
# 3805664  male_ingu
# 3805665  male_ingu
# 3805666  male_ingu
# 3805667  male_ingu
#
# [1902834 rows x 7 columns]

# %%
yp_df_2[yp_df_2['성별']=='female_ingu']
# Out:
#          hour gu_name dong_name                성별연령대        인구      연령대  \
# 3805668     0    영등포구     영등포본동  under10_female_ingu  0.291928  under10
# 3805669     0    영등포구     영등포본동  under10_female_ingu  0.149363  under10
# 3805670     0    영등포구     영등포본동  under10_female_ingu  0.003061  under10
# 3805671     0    영등포구     영등포본동  under10_female_ingu  0.265973  under10
# 3805672     0    영등포구     영등포본동  under10_female_ingu  0.141304  under10
# ...       ...     ...       ...                  ...       ...      ...
# 5708497    23    영등포구      대림3동  upper80_female_ingu  0.203570  upper80
# 5708498    23    영등포구      대림3동  upper80_female_ingu  0.923317  upper80
# 5708499    23    영등포구      대림3동  upper80_female_ingu  0.568758  upper80
# 5708500    23    영등포구      대림3동  upper80_female_ingu  0.110731  upper80
# 5708501    23    영등포구      대림3동  upper80_female_ingu  0.171656  upper80
#
#                   성별
# 3805668  female_ingu
# 3805669  female_ingu
# 3805670  female_ingu
# 3805671  female_ingu
# 3805672  female_ingu
# ...              ...
# 5708497  female_ingu
# 5708498  female_ingu
# 5708499  female_ingu
# 5708500  female_ingu
# 5708501  female_ingu
#
# [1902834 rows x 7 columns]

# %%
analysis1_df = yp_df_unisex.groupby('hour').sum()

# %%
analysis1_df
# Out:
#                  인구
# hour
# 0     194006.583718
# 1     191874.727889
# 2     190111.045369
# 3     188437.643557
# 4     188604.621580
# 5     190179.757706
# 6     196755.085154
# 7     225631.257005
# 8     250176.781598
# 9     259824.941546
# 10    263190.502423
# 11    265676.650196
# 12    264217.856881
# 13    261401.182021
# 14    258401.814114
# 15    255411.594650
# 16    250678.756653
# 17    239918.886529
# 18    226813.749569
# 19    216871.051864
# 20    209878.632065
# 21    202407.113794
# 22    195719.721920
# 23    189689.923329

# %%
analysis1_df['남성'] = yp_df_2[yp_df_2['성별']=='male_ingu'].groupby('hour').sum()
analysis1_df['여성'] = yp_df_2[yp_df_2['성별']=='female_ingu'].groupby('hour').sum()
analysis1_df['debug'] = analysis1_df.apply(lambda row:row['남성']+row['여성'],axis=1)

# %%
analysis1_df
# Out:
#                  인구             남성             여성          debug
# hour
# 0     194006.583718   87645.950411   83666.367734  171312.318146
# 1     191874.727889   86411.336857   83026.111306  169437.448163
# 2     190111.045369   85335.966923   82538.623881  167874.590804
# 3     188437.643557   84328.493369   82029.960605  166358.453975
# 4     188604.621580   84176.010494   82453.976289  166629.986783
# 5     190179.757706   85708.062638   82992.007766  168700.070404
# 6     196755.085154   90665.613583   84714.630578  175380.244161
# 7     225631.257005  107679.423747   95338.712522  203018.136269
# 8     250176.781598  119892.442228  106192.185663  226084.627891
# 9     259824.941546  123990.924890  111017.547318  235008.472208
# 10    263190.502423  125255.858279  112829.807457  238085.665736
# 11    265676.650196  126829.838305  113547.300602  240377.138908
# 12    264217.856881  125788.447235  112993.589754  238782.036988
# 13    261401.182021  124450.243713  111514.431230  235964.674943
# 14    258401.814114  122994.551818  110222.204322  233216.756140
# 15    255411.594650  121124.715202  109153.967273  230278.682475
# 16    250678.756653  117855.013074  107761.092491  225616.105565
# 17    239918.886529  111494.342048  103689.490858  215183.832906
# 18    226813.749569  104332.076792   98159.576026  202491.652818
# 19    216871.051864   98805.178065   93992.492477  192797.670542
# 20    209878.632065   95309.573467   90656.721090  185966.294558
# 21    202407.113794   91737.162418   86807.118231  178544.280650
# 22    195719.721920   88558.956469   83387.068679  171946.025148
# 23    189689.923329   85613.565328   80750.573687  166364.139015

# %%
yp_df_10000_clean.head()
# Out:
#    hour gu_name dong_name         성별연령대        인구      연령대     성별
# 0     0    영등포구     영등포본동  under10_ingu  0.477690  under10  total
# 1     0    영등포구     영등포본동  under10_ingu  0.261749  under10  total
# 2     0    영등포구     영등포본동  under10_ingu  0.003061  under10  total
# 3     0    영등포구     영등포본동  under10_ingu  0.683299  under10  total
# 4     0    영등포구     영등포본동  under10_ingu  0.218001  under10  total

# %%
mapo_df = pd.read_excel("../data/moving_population/ingu_hour_mapo.xlsx",sheet_name=0)

# %%
df = pd.concat([yp_df, mapo_df])
print("Column headings:")
print(df.columns)
print(df.columns)
# Out:
# Column headings:
# Index(['date', 'hour', 'longitude', 'latitude', 'gu_code', 'gu_name',
#        'dong_code', 'dong_name', 'under10_ingu', 'under20_ingu',
#        'under30_ingu', 'under40_ingu', 'under50_ingu', 'under60_ingu',
#        'under70_ingu', 'under80_ingu', 'upper80_ingu', 'under10_male_ingu',
#        'under20_male_ingu', 'under30_male_ingu', 'under40_male_ingu',
#        'under50_male_ingu', 'under60_male_ingu', 'under70_male_ingu',
#        'under80_male_ingu', 'upper80_male_ingu', 'under10_female_ingu',
#        'under20_female_ingu', 'under30_female_ingu', 'under40_female_ingu',
#        'under50_female_ingu', 'under60_female_ingu', 'under70_female_ingu',
#        'under80_female_ingu', 'upper80_female_ingu'],
#       dtype='object')
# Index(['date', 'hour', 'longitude', 'latitude', 'gu_code', 'gu_name',
#        'dong_code', 'dong_name', 'under10_ingu', 'under20_ingu',
#        'under30_ingu', 'under40_ingu', 'under50_ingu', 'under60_ingu',
#        'under70_ingu', 'under80_ingu', 'upper80_ingu', 'under10_male_ingu',
#        'under20_male_ingu', 'under30_male_ingu', 'under40_male_ingu',
#        'under50_male_ingu', 'under60_male_ingu', 'under70_male_ingu',
#        'under80_male_ingu', 'upper80_male_ingu', 'under10_female_ingu',
#        'under20_female_ingu', 'under30_female_ingu', 'under40_female_ingu',
#        'under50_female_ingu', 'under60_female_ingu', 'under70_female_ingu',
#        'under80_female_ingu', 'upper80_female_ingu'],
#       dtype='object')

# %%
info['under80_ingu']
# Out:
# 0         2.039465
# 1         2.818753
# 2         0.729360
# 3         2.972929
# 4         1.621038
# 5         3.696146
# 6         1.459867
# 7         4.050965
# 8         0.690941
# 9         2.748141
# 10        1.611013
# 11        1.483147
# 12        0.529442
# 13        1.363903
# 14        0.300597
# 15        0.581599
# 16        0.748841
# 17        2.529473
# 18        2.100494
# 19        0.589867
# 20        0.440920
# 21        0.642770
# 22        0.647057
# 23        2.345369
# 24        3.089817
# 25        0.638893
# 26        1.219475
# 27        2.878496
# 28        2.672629
# 29        0.291874
#             ...
# 211396    2.649142
# 211397    1.453178
# 211398    2.679471
# 211399    2.117583
# 211400    0.264328
# 211401    1.816424
# 211402    0.801409
# 211403    1.475979
# 211404    2.598006
# 211405    3.468964
# 211406    2.944390
# 211407    2.570824
# 211408    2.472064
# 211409    1.357797
# 211410    0.518996
# 211411    0.616811
# 211412    2.321954
# 211413    0.763233
# 211414    1.487381
# 211415    1.338114
# 211416    1.326214
# 211417    3.126361
# 211418    0.797135
# 211419    1.694001
# 211420    0.810253
# 211421    2.495556
# 211422    6.493694
# 211423    3.563040
# 211424    0.699206
# 211425    1.269684
# Name: under80_ingu, Length: 211426, dtype: float64

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211426 entries, 0 to 211425
# Data columns (total 35 columns):
# date                   211426 non-null int64
# hour                   211426 non-null int64
# longitude              211426 non-null float64
# latitude               211426 non-null float64
# gu_code                211426 non-null int64
# gu_name                211426 non-null object
# dong_code              211426 non-null int64
# dong_name              211426 non-null object
# under10_ingu           211426 non-null float64
# under20_ingu           211426 non-null float64
# under30_ingu           211426 non-null float64
# under40_ingu           211426 non-null float64
# under50_ingu           211426 non-null float64
# under60_ingu           211426 non-null float64
# under70_ingu           211426 non-null float64
# under80_ingu           211426 non-null float64
# upper80_ingu           211426 non-null float64
# under10_male_ingu      211426 non-null float64
# under20_male_ingu      211426 non-null float64
# under30_male_ingu      211426 non-null float64
# under40_male_ingu      211426 non-null float64
# under50_male_ingu      211426 non-null float64
# under60_male_ingu      211426 non-null float64
# under70_male_ingu      211426 non-null float64
# under80_male_ingu      211426 non-null float64
# upper80_male_ingu      211426 non-null float64
# under10_female_ingu    211426 non-null float64
# under20_female_ingu    211426 non-null float64
# under30_female_ingu    211426 non-null float64
# under40_female_ingu    211426 non-null float64
# under50_female_ingu    211426 non-null float64
# under60_female_ingu    211426 non-null float64
# under70_female_ingu    211426 non-null float64
# under80_female_ingu    211426 non-null float64
# upper80_female_ingu    211426 non-null float64
# dtypes: float64(29), int64(4), object(2)
# memory usage: 56.5+ MB

# %%
info['hour'].value_counts().plot(kind='bar')

# %%
plt.show()

# %%
sns.distplot(info.loc[info['under30_ingu'].notnull(), 'under30_ingu'])
plt.title('under30_ingu')
plt.show()

# %%
profile = pp.ProfileReport(info, title='Pandas Profiling Report', html={'style':{'full_width':True}})
# Out:
# HBox(children=(FloatProgress(value=0.0, description='variables', max=35.0, style=ProgressStyle(description_wid…
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-34-0ae0e641f506> in <module>
# ----> 1 profile = pp.ProfileReport(info, title='Pandas Profiling Report', html={'style':{'full_width':True}})
#
# C:\project\venv\dacon\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, minimal, config_file, **kwargs)
#      68
#      69         # Get dataset statistics
# ---> 70         description_set = describe_df(df)
#      71
#      72         # Build report structure
#
# C:\project\venv\dacon\lib\site-packages\pandas_profiling\model\describe.py in describe(df)
#     600             with multiprocessing.pool.ThreadPool(pool_size) as executor:
#     601                 for i, (column, description) in enumerate(
# --> 602                     executor.imap_unordered(multiprocess_1d, args)
#     603                 ):
#     604                     series_description[column] = description
#
# ~\AppData\Local\Programs\Python\Python37\lib\multiprocessing\pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# ~\AppData\Local\Programs\Python\Python37\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# C:\project\venv\dacon\lib\site-packages\pandas_profiling\model\describe.py in multiprocess_1d(args)
#     386     """
#     387     column, series = args
# --> 388     return column, describe_1d(series)
#     389
#     390
#
# C:\project\venv\dacon\lib\site-packages\pandas_profiling\model\describe.py in describe_1d(series)
#     366         if series_description["type"] in type_to_func:
#     367             series_description.update(
# --> 368                 type_to_func[series_description["type"]](series, series_description)
#     369             )
#     370         else:
#
# C:\project\venv\dacon\lib\site-packages\pandas_profiling\model\describe.py in describe_numeric_1d(series, series_description)
#      66         "skewness": series.skew(),
#      67         "sum": series.sum(),
# ---> 68         "mad": series.mad(),
#      69         "n_zeros": (len(series) - np.count_nonzero(series)),
#      70         "histogram_data": series,
#
# C:\project\venv\dacon\lib\site-packages\pandas\core\generic.py in mad(self, axis, skipna, level)
#   10007         upper percentiles. By default the lower percentile is ``25`` and the
#   10008         upper percentile is ``75``. The ``50`` percentile is the
# > 10009         same as the median.
#   10010
#   10011         For object data (e.g. strings or timestamps), the result's index
#
# C:\project\venv\dacon\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#
# C:\project\venv\dacon\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#
# C:\project\venv\dacon\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#
# C:\project\venv\dacon\lib\site-packages\pandas\core\computation\expressions.py in <module>
#     167
#     168 # turn myself on
# --> 169 set_use_numexpr(get_option("compute.use_numexpr"))
#     170
#     171
#
# C:\project\venv\dacon\lib\site-packages\pandas\_config\config.py in __call__(self, *args, **kwds)
#     231
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#     235     @property
#
# C:\project\venv\dacon\lib\site-packages\pandas\_config\config.py in _get_option(pat, silent)
#     100
#     101 def _get_option(pat, silent=False):
# --> 102     key = _get_single_key(pat, silent)
#     103
#     104     # walk the nested dict
#
# C:\project\venv\dacon\lib\site-packages\pandas\_config\config.py in _get_single_key(pat, silent)
#      86         if not silent:
#      87             _warn_if_deprecated(pat)
# ---> 88         raise OptionError("No such keys(s): {pat!r}".format(pat=pat))
#      89     if len(keys) > 1:
#      90         raise OptionError("Pattern matched multiple keys")
#
# OptionError: "No such keys(s): 'compute.use_numexpr'"
